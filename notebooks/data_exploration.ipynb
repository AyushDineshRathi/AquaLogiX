# %%
import xarray as xr
import os

# Define the path to your raw data file
# Make sure you have downloaded a file into this directory
file_name = '19970728_prof.nc' 
file_path = os.path.join('..', 'data', 'raw', file_name)

# Check if the file exists before trying to open it
if os.path.exists(file_path):
    # Open the NetCDF file using xarray
    argo_dataset = xr.open_dataset(file_path)

    # Print the dataset object to see its structure
    print("--- Dataset Structure ---")
    with open("output.txt", "w") as f:
        f.write(argo_dataset.__str__())
    print(argo_dataset)

    # Print the specific variables available
    print("\n--- Data Variables ---")
    for var in argo_dataset.data_vars:
        print(var)
else:
    print(f"Error: The file was not found at {file_path}")
    print("Please make sure you've downloaded an ARGO .nc file and placed it in the data/raw/ directory.")
# Out:
# --- Dataset Structure ---
# <xarray.Dataset> Size: 6kB
# Dimensions:                       (N_PROF: 1, N_PARAM: 2, N_LEVELS: 102,
#                                    N_CALIB: 1, N_HISTORY: 0)
# Dimensions without coordinates: N_PROF, N_PARAM, N_LEVELS, N_CALIB, N_HISTORY
# Data variables: (12/58)
#     DATA_TYPE                     object 8B ...
#     FORMAT_VERSION                object 8B ...
#     HANDBOOK_VERSION              object 8B ...
#     REFERENCE_DATE_TIME           object 8B ...
#     DATE_CREATION                 object 8B ...
#     DATE_UPDATE                   object 8B ...
#     ...                            ...
#     HISTORY_ACTION                (N_HISTORY, N_PROF) object 0B ...
#     HISTORY_PARAMETER             (N_HISTORY, N_PROF) object 0B ...
#     HISTORY_START_PRES            (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_STOP_PRES             (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_PREVIOUS_VALUE        (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_QCTEST                (N_HISTORY, N_PROF) object 0B ...
# Attributes:
#     title:                Argo float vertical profile
#     institution:          US GDAC
#     source:               Argo float
#     history:              2018-10-12T17:47:09Z
#     user_manual_version:  3.1
#     Conventions:          Argo-3.1 CF-1.6
#     featureType:          trajectoryProfile
#
# --- Data Variables ---
# DATA_TYPE
# FORMAT_VERSION
# HANDBOOK_VERSION
# REFERENCE_DATE_TIME
# DATE_CREATION
# DATE_UPDATE
# PLATFORM_NUMBER
# PROJECT_NAME
# PI_NAME
# STATION_PARAMETERS
# CYCLE_NUMBER
# DIRECTION
# DATA_CENTRE
# DC_REFERENCE
# DATA_STATE_INDICATOR
# DATA_MODE
# PLATFORM_TYPE
# FLOAT_SERIAL_NO
# FIRMWARE_VERSION
# WMO_INST_TYPE
# JULD
# JULD_QC
# JULD_LOCATION
# LATITUDE
# LONGITUDE
# POSITION_QC
# POSITIONING_SYSTEM
# PROFILE_PRES_QC
# PROFILE_TEMP_QC
# VERTICAL_SAMPLING_SCHEME
# CONFIG_MISSION_NUMBER
# PRES
# PRES_QC
# PRES_ADJUSTED
# PRES_ADJUSTED_QC
# PRES_ADJUSTED_ERROR
# TEMP
# TEMP_QC
# TEMP_ADJUSTED
# TEMP_ADJUSTED_QC
# TEMP_ADJUSTED_ERROR
# PARAMETER
# SCIENTIFIC_CALIB_EQUATION
# SCIENTIFIC_CALIB_COEFFICIENT
# SCIENTIFIC_CALIB_COMMENT
# SCIENTIFIC_CALIB_DATE
# HISTORY_INSTITUTION
# HISTORY_STEP
# HISTORY_SOFTWARE
# HISTORY_SOFTWARE_RELEASE
# HISTORY_REFERENCE
# HISTORY_DATE
# HISTORY_ACTION
# HISTORY_PARAMETER
# HISTORY_START_PRES
# HISTORY_STOP_PRES
# HISTORY_PREVIOUS_VALUE
# HISTORY_QCTEST

# %%
import xarray as xr
import os

file_name = 'nodc_D1901049_343.nc' 
file_path = os.path.join('..', 'data', 'raw', file_name)

if os.path.exists(file_path):
    argo_dataset = xr.open_dataset(file_path)

    # Print the dataset object to see its structure
    print("--- Dataset Structure ---")
    with open("output.txt", "w") as f:
        f.write(argo_dataset.__str__())
    for var in argo_dataset.data_vars:
        print(var)

    # Print the specific variables available
    print("\n--- Data Variables ---")
    for var in argo_dataset.data_vars:
        print(var)
else:
    print(f"Error: The file was not found at {file_path}")
    print("Please make sure you've downloaded an ARGO .nc file and placed it in the data/raw/ directory.")
# Out:
# --- Dataset Structure ---
# data_type
# format_version
# handbook_version
# reference_date_time
# date_creation
# date_update
# platform_number
# project_name
# pi_name
# station_parameters
# cycle_number
# direction
# data_centre
# dc_reference
# data_state_indicator
# data_mode
# platform_type
# float_serial_no
# firmware_version
# wmo_inst_type
# juld
# juld_qc
# juld_location
# latitude
# longitude
# position_qc
# positioning_system
# vertical_sampling_scheme
# config_mission_number
# profile_pres_qc
# profile_temp_qc
# profile_psal_qc
# pres
# pres_qc
# pres_adjusted
# pres_adjusted_qc
# pres_adjusted_error
# temp
# temp_qc
# temp_adjusted
# temp_adjusted_qc
# temp_adjusted_error
# psal
# psal_qc
# psal_adjusted
# psal_adjusted_qc
# psal_adjusted_error
# parameter
# scientific_calib_equation
# scientific_calib_coefficient
# scientific_calib_comment
# scientific_calib_date
# history_institution
# history_step
# history_software
# history_software_release
# history_reference
# history_date
# history_action
# history_parameter
# history_start_pres
# history_stop_pres
# history_previous_value
# history_qctest
# crs
#
# --- Data Variables ---
# data_type
# format_version
# handbook_version
# reference_date_time
# date_creation
# date_update
# platform_number
# project_name
# pi_name
# station_parameters
# cycle_number
# direction
# data_centre
# dc_reference
# data_state_indicator
# data_mode
# platform_type
# float_serial_no
# firmware_version
# wmo_inst_type
# juld
# juld_qc
# juld_location
# latitude
# longitude
# position_qc
# positioning_system
# vertical_sampling_scheme
# config_mission_number
# profile_pres_qc
# profile_temp_qc
# profile_psal_qc
# pres
# pres_qc
# pres_adjusted
# pres_adjusted_qc
# pres_adjusted_error
# temp
# temp_qc
# temp_adjusted
# temp_adjusted_qc
# temp_adjusted_error
# psal
# psal_qc
# psal_adjusted
# psal_adjusted_qc
# psal_adjusted_error
# parameter
# scientific_calib_equation
# scientific_calib_coefficient
# scientific_calib_comment
# scientific_calib_date
# history_institution
# history_step
# history_software
# history_software_release
# history_reference
# history_date
# history_action
# history_parameter
# history_start_pres
# history_stop_pres
# history_previous_value
# history_qctest
# crs

# %%
import xarray as xr
import os

file_to_inspect = 'nodc_D1901049_343.nc'

file_path = os.path.join('..', 'data', 'raw', file_to_inspect)

if not os.path.exists(file_path):
    print(f"Error: The file was not found at {file_path}")
    print("Please make sure the file name is correct and it's in the data/raw/ directory.")
else:
    with xr.open_dataset(file_path) as ds:
        print(f"--- Parameters available in: {file_to_inspect} ---\n")
        
        if not ds.data_vars:
            print("No data variables found in this file.")
        else:
            # Loop through each data variable in the file
            for var_name in ds.data_vars:
                variable = ds[var_name]
                
                # Print the short name of the parameter
                print(f"Parameter Name: {var_name}")
                
                # Print the descriptive attributes
                if variable.attrs:
                    long_name = variable.attrs.get('long_name', 'N/A')
                    units = variable.attrs.get('units', 'N/A')
                    print(f"  - Description: {long_name}")
                    print(f"  - Units: {units}")
                else:
                    print("  - (No descriptive attributes found)")
                print("-" * 25) # Add a separator for readability
# Out:
# --- Parameters available in: nodc_D1901049_343.nc ---
#
# Parameter Name: data_type
#   - Description: Data type
#   - Units: N/A
# -------------------------
# Parameter Name: format_version
#   - Description: File format version
#   - Units: N/A
# -------------------------
# Parameter Name: handbook_version
#   - Description: Data handbook version
#   - Units: N/A
# -------------------------
# Parameter Name: reference_date_time
#   - Description: Date of reference for Julian days
#   - Units: N/A
# -------------------------
# Parameter Name: date_creation
#   - Description: Date of file creation
#   - Units: N/A
# -------------------------
# Parameter Name: date_update
#   - Description: Date of update of this file
#   - Units: N/A
# -------------------------
# Parameter Name: platform_number
#   - Description: Float unique identifier
#   - Units: N/A
# -------------------------
# Parameter Name: project_name
#   - Description: Name of the project
#   - Units: N/A
# -------------------------
# Parameter Name: pi_name
#   - Description: Name of the principal investigator
#   - Units: N/A
# -------------------------
# Parameter Name: station_parameters
#   - Description: List of available parameters for the station
#   - Units: N/A
# -------------------------
# Parameter Name: cycle_number
#   - Description: Float cycle number
#   - Units: N/A
# -------------------------
# Parameter Name: direction
#   - Description: Direction of the station profiles
#   - Units: N/A
# -------------------------
# Parameter Name: data_centre
#   - Description: Data centre in charge of float data processing
#   - Units: N/A
# -------------------------
# Parameter Name: dc_reference
#   - Description: Station unique identifier in data centre
#   - Units: N/A
# -------------------------
# Parameter Name: data_state_indicator
#   - Description: Degree of processing the data have passed through
#   - Units: N/A
# -------------------------
# Parameter Name: data_mode
#   - Description: Delayed mode or real time data
#   - Units: N/A
# -------------------------
# Parameter Name: platform_type
#   - Description: Type of float
#   - Units: N/A
# -------------------------
# Parameter Name: float_serial_no
#   - Description: Serial number of the float
#   - Units: N/A
# -------------------------
# Parameter Name: firmware_version
#   - Description: Instrument firmware version
#   - Units: N/A
# -------------------------
# Parameter Name: wmo_inst_type
#   - Description: Coded instrument type
#   - Units: N/A
# -------------------------
# Parameter Name: juld
#   - Description: Julian day (UTC) of the station relative to REFERENCE_DATE_TIME
#   - Units: N/A
# -------------------------
# Parameter Name: juld_qc
#   - Description: Quality on date and time
#   - Units: N/A
# -------------------------
# Parameter Name: juld_location
#   - Description: Julian day (UTC) of the location relative to REFERENCE_DATE_TIME
#   - Units: N/A
# -------------------------
# Parameter Name: latitude
#   - Description: Latitude of the station, best estimate
#   - Units: degree_north
# -------------------------
# Parameter Name: longitude
#   - Description: Longitude of the station, best estimate
#   - Units: degree_east
# -------------------------
# Parameter Name: position_qc
#   - Description: Quality on position (latitude and longitude)
#   - Units: N/A
# -------------------------
# Parameter Name: positioning_system
#   - Description: Positioning system
#   - Units: N/A
# -------------------------
# Parameter Name: vertical_sampling_scheme
#   - Description: Vertical sampling scheme
#   - Units: N/A
# -------------------------
# Parameter Name: config_mission_number
#   - Description: Unique number denoting the missions performed by the float
#   - Units: N/A
# -------------------------
# Parameter Name: profile_pres_qc
#   - Description: Global quality flag of PRES profile
#   - Units: N/A
# -------------------------
# Parameter Name: profile_temp_qc
#   - Description: Global quality flag of TEMP profile
#   - Units: N/A
# -------------------------
# Parameter Name: profile_psal_qc
#   - Description: Global quality flag of PSAL profile
#   - Units: N/A
# -------------------------
# Parameter Name: pres
#   - Description: Sea water pressure, equals 0 at sea-level
#   - Units: decibar
# -------------------------
# Parameter Name: pres_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: pres_adjusted
#   - Description: Sea water pressure, equals 0 at sea-level
#   - Units: decibar
# -------------------------
# Parameter Name: pres_adjusted_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: pres_adjusted_error
#   - Description: Contains the error on the adjusted values as determined by the delayed mode QC process
#   - Units: decibar
# -------------------------
# Parameter Name: temp
#   - Description: Sea temperature in-situ ITS-90 scale
#   - Units: degree_Celsius
# -------------------------
# Parameter Name: temp_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: temp_adjusted
#   - Description: Sea temperature in-situ ITS-90 scale
#   - Units: degree_Celsius
# -------------------------
# Parameter Name: temp_adjusted_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: temp_adjusted_error
#   - Description: Contains the error on the adjusted values as determined by the delayed mode QC process
#   - Units: degree_Celsius
# -------------------------
# Parameter Name: psal
#   - Description: Practical salinity
#   - Units: psu
# -------------------------
# Parameter Name: psal_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: psal_adjusted
#   - Description: Practical salinity
#   - Units: psu
# -------------------------
# Parameter Name: psal_adjusted_qc
#   - Description: quality flag
#   - Units: N/A
# -------------------------
# Parameter Name: psal_adjusted_error
#   - Description: Contains the error on the adjusted values as determined by the delayed mode QC process
#   - Units: psu
# -------------------------
# Parameter Name: parameter
#   - Description: List of parameters with calibration information
#   - Units: N/A
# -------------------------
# Parameter Name: scientific_calib_equation
#   - Description: Calibration equation for this parameter
#   - Units: N/A
# -------------------------
# Parameter Name: scientific_calib_coefficient
#   - Description: Calibration coefficients for this equation
#   - Units: N/A
# -------------------------
# Parameter Name: scientific_calib_comment
#   - Description: Comment applying to this parameter calibration
#   - Units: N/A
# -------------------------
# Parameter Name: scientific_calib_date
#   - Description: Date of calibration
#   - Units: N/A
# -------------------------
# Parameter Name: history_institution
#   - Description: Institution which performed action
#   - Units: N/A
# -------------------------
# Parameter Name: history_step
#   - Description: Step in data processing
#   - Units: N/A
# -------------------------
# Parameter Name: history_software
#   - Description: Name of software which performed action
#   - Units: N/A
# -------------------------
# Parameter Name: history_software_release
#   - Description: Version/release of software which performed action
#   - Units: N/A
# -------------------------
# Parameter Name: history_reference
#   - Description: Reference of database
#   - Units: N/A
# -------------------------
# Parameter Name: history_date
#   - Description: Date the history record was created
#   - Units: N/A
# -------------------------
# Parameter Name: history_action
#   - Description: Action performed on data
#   - Units: N/A
# -------------------------
# Parameter Name: history_parameter
#   - Description: Station parameter action is performed on
#   - Units: N/A
# -------------------------
# Parameter Name: history_start_pres
#   - Description: Start pressure action applied on
#   - Units: decibar
# -------------------------
# Parameter Name: history_stop_pres
#   - Description: Stop pressure action applied on
#   - Units: decibar
# -------------------------
# Parameter Name: history_previous_value
#   - Description: Parameter/Flag previous value before action
#   - Units: N/A
# -------------------------
# Parameter Name: history_qctest
#   - Description: Documentation of tests performed, tests failed (in hex form)
#   - Units: N/A
# -------------------------
# Parameter Name: crs
#   - Description: Coordinate Reference System
#   - Units: N/A
# -------------------------
